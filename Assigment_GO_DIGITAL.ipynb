# %%
'''Assignment: 

Basic Libraries needed 1. Pandas 2. Numpy'''
# Out:
# 'Assignment: \n\nBasic Libraries needed 1. Pandas 2. Numpy'

# %%
import pandas as pd
import numpy as np

# %%
employee_data=pd.read_csv('/content/drive/MyDrive/go digital/employee_data.csv')

# %%
insurance_data=pd.read_csv('/content/drive/MyDrive/go digital/insurance_data.csv')

# %%
vendor_data=pd.read_csv('/content/drive/MyDrive/go digital/vendor_data.csv')

# %%
employee_data.head()
# Out:
#      AGENT_ID      AGENT_NAME DATE_OF_JOINING          ADDRESS_LINE1  \
# 0  AGENT00001       Ray Johns      1993-06-05       1402 Maggies Way
# 1  AGENT00002   Angelo Borjon      2005-12-27         414 Tanya Pass
# 2  AGENT00003  Candy Spellman      2003-09-02    606 National Street
# 3  AGENT00004      Mary Smith      2004-09-23  235 Hugh Thomas Drive
# 4  AGENT00005    Mildred Diaz      2011-06-21  3426 Broadview Street
#
#   ADDRESS_LINE2              CITY STATE  POSTAL_CODE  EMP_ROUTING_NUMBER  \
# 0           NaN  Waterbury Center    VT         5677            34584958
# 1           NaN       Panama City    FL        32404           107363763
# 2          #306      Fayetteville    AR        72701            81744097
# 3           NaN       Panama City    FL        32404            67563771
# 4           NaN        Montgomery    AL        36110           114951317
#
#       EMP_ACCT_NUMBER
# 0  HKUN51252328472585
# 1  OPIS19290040088204
# 2  YSCJ67489688482590
# ...

# %%
insurance_data.head()
# Out:
#          TXN_DATE_TIME TRANSACTION_ID CUSTOMER_ID POLICY_NUMBER POLICY_EFF_DT  \
# 0  2020-06-01 00:00:00    TXN00000001   A00003822   PLC00008468    2015-06-23
# 1  2020-06-01 00:00:00    TXN00000002   A00008149   PLC00009594    2018-04-21
# 2  2020-06-01 00:00:00    TXN00000003   A00003172   PLC00007969    2019-10-03
# 3  2020-06-01 00:00:00    TXN00000004   A00007572   PLC00009292    2016-11-29
# 4  2020-06-01 00:00:00    TXN00000005   A00008173   PLC00000204    2011-12-26
#
#       LOSS_DT   REPORT_DT INSURANCE_TYPE  PREMIUM_AMOUNT  CLAIM_AMOUNT  ...  \
# 0  2020-05-16  2020-05-21         Health          157.13          9000  ...
# 1  2020-05-13  2020-05-18       Property          141.71         26000  ...
# 2  2020-05-21  2020-05-26       Property          157.24         13000  ...
# 3  2020-05-14  2020-05-19         Health          172.87         16000  ...
# 4  2020-05-17  2020-05-22         Travel           88.53          3000  ...
#
# ...

# %%
vendor_data.head()
# Out:
#    VENDOR_ID              VENDOR_NAME                   ADDRESS_LINE1  \
# 0  VNDR00001  King, Proctor and Jones        2027 North Shannon Drive
# 1  VNDR00002               Garcia Ltd          5701 East Shirley Lane
# 2  VNDR00003               Cherry LLC            1217 Cottondale Road
# 3  VNDR00004              Mays-Benson  227 West Montgomery Cross Road
# 4  VNDR00005               Wilson PLC            23 North Hill Street
#
#   ADDRESS_LINE2          CITY STATE  POSTAL_CODE
# 0            #5  Fayetteville    AR        72703
# 1           NaN    Montgomery    AL        36117
# 2           NaN    Montgomery    AL        36109
# 3          #736      Savannah    GA        31406
# 4           NaN     Nashville    TN        37210

# %% [markdown]
# TASK 1

# %%
df1=pd.merge(insurance_data,employee_data,on="AGENT_ID",how="left")

# %%
df1.head()
# Out:
#          TXN_DATE_TIME TRANSACTION_ID CUSTOMER_ID POLICY_NUMBER POLICY_EFF_DT  \
# 0  2020-06-01 00:00:00    TXN00000001   A00003822   PLC00008468    2015-06-23
# 1  2020-06-01 00:00:00    TXN00000002   A00008149   PLC00009594    2018-04-21
# 2  2020-06-01 00:00:00    TXN00000003   A00003172   PLC00007969    2019-10-03
# 3  2020-06-01 00:00:00    TXN00000004   A00007572   PLC00009292    2016-11-29
# 4  2020-06-01 00:00:00    TXN00000005   A00008173   PLC00000204    2011-12-26
#
#       LOSS_DT   REPORT_DT INSURANCE_TYPE  PREMIUM_AMOUNT  CLAIM_AMOUNT  ...  \
# 0  2020-05-16  2020-05-21         Health          157.13          9000  ...
# 1  2020-05-13  2020-05-18       Property          141.71         26000  ...
# 2  2020-05-21  2020-05-26       Property          157.24         13000  ...
# 3  2020-05-14  2020-05-19         Health          172.87         16000  ...
# 4  2020-05-17  2020-05-22         Travel           88.53          3000  ...
#
# ...

# %%
df2=pd.merge(df1,vendor_data,on="VENDOR_ID",how="left")

# %%
df2.columns
# Out:
# Index(['TXN_DATE_TIME', 'TRANSACTION_ID', 'CUSTOMER_ID', 'POLICY_NUMBER',
#        'POLICY_EFF_DT', 'LOSS_DT', 'REPORT_DT', 'INSURANCE_TYPE',
#        'PREMIUM_AMOUNT', 'CLAIM_AMOUNT', 'CUSTOMER_NAME', 'ADDRESS_LINE1_x',
#        'ADDRESS_LINE2_x', 'CITY_x', 'STATE_x', 'POSTAL_CODE_x', 'SSN',
#        'MARITAL_STATUS', 'AGE', 'TENURE', 'EMPLOYMENT_STATUS',
#        'NO_OF_FAMILY_MEMBERS', 'RISK_SEGMENTATION', 'HOUSE_TYPE',
#        'SOCIAL_CLASS', 'ROUTING_NUMBER', 'ACCT_NUMBER',
#        'CUSTOMER_EDUCATION_LEVEL', 'CLAIM_STATUS', 'INCIDENT_SEVERITY',
#        'AUTHORITY_CONTACTED', 'ANY_INJURY', 'POLICE_REPORT_AVAILABLE',
#        'INCIDENT_STATE', 'INCIDENT_CITY', 'INCIDENT_HOUR_OF_THE_DAY',
#        'AGENT_ID', 'VENDOR_ID', 'AGENT_NAME', 'DATE_OF_JOINING',
#        'ADDRESS_LINE1_y', 'ADDRESS_LINE2_y', 'CITY_y', 'STATE_y',
#        'POSTAL_CODE_y', 'EMP_ROUTING_NUMBER', 'EMP_ACCT_NUMBER', 'VENDOR_NAME',
#        'ADDRESS_LINE1', 'ADDRESS_LINE2', 'CITY', 'STATE', 'POSTAL_CODE'],
# ...

# %%
df2.sample(10)
# Out:
#             TXN_DATE_TIME TRANSACTION_ID CUSTOMER_ID POLICY_NUMBER  \
# 7135  2021-03-09 00:00:00    TXN00007136   A00001036   PLC00009598
# 6497  2021-02-12 00:00:00    TXN00006498   A00002475   PLC00005793
# 5024  2020-12-19 00:00:00    TXN00005025   A00002517   PLC00003456
# 4002  2020-11-09 00:00:00    TXN00004003   A00001241   PLC00002616
# 4358  2020-11-23 00:00:00    TXN00004359   A00005350   PLC00001882
# 2862  2020-09-24 00:00:00    TXN00002863   A00009792   PLC00002414
# 567   2020-06-22 00:00:00    TXN00000568   A00002301   PLC00007142
# 6854  2021-02-25 00:00:00    TXN00006855   A00007552   PLC00001546
# 9975  2021-06-30 00:00:00    TXN00009976   A00002659   PLC00005667
# 9348  2021-06-05 00:00:00    TXN00009349   A00006152   PLC00005840
#
#      POLICY_EFF_DT     LOSS_DT   REPORT_DT INSURANCE_TYPE  PREMIUM_AMOUNT  \
# 7135    2019-05-04  2021-03-08  2021-03-08          Motor          108.89
# 6497    2017-07-24  2021-02-10  2021-02-10           Life           73.37
# ...

# %% [markdown]
# TASK 2:
# Business Leader wants to find Top 3 Insurance Type where we are getting
# most insurance claims?

# %%
insurance_data["INSURANCE_TYPE"].value_counts().nlargest(3)
# Out:
# Property    1692
# Mobile      1692
# Health      1690
# Name: INSURANCE_TYPE, dtype: int64

# %% [markdown]
# TASK 3:
# Business Leader wants to find Top 5 States where we are getting most insurance claims
# for customer belonging to HIGH(H) risk segment?

# %%
insurance_data[insurance_data["RISK_SEGMENTATION"]=="H"].STATE.value_counts().nlargest(5)
# Out:
# CA    148
# AZ    105
# FL    104
# TN    100
# AR     97
# Name: STATE, dtype: int64

# %% [markdown]
# TASK 4:
# Business wants to create a new variable “COLOCATION” which will have following values IF
# Customer State == Incident State == Agent Address State THEN 1 ELSE 0
# Find the mean of this new colum

# %%
df2["COLOCATION"]=(df2["STATE"]==df2["INCIDENT_STATE"])&(df2["INCIDENT_STATE"]==df2["STATE"])

# %%
df2["COLOCATION"]=df2.COLOCATION.astype("int")

# %%
df2["COLOCATION"].mean()# finding mean
# Out:
# 0.0449

# %% [markdown]
# Task 5: Data entry error was detected in the data and you are required to correct it. If for any
# claim transaction “AUTHORITY_CONTACTED” is NOT “Police” and POLICE_AVAILABLE == 1
# Then Update “AUTHORITY_CONTACTED” to Police.

# %%
df2["AUTHORITY_CONTACTED"].unique()
# Out:
# array(['Police', 'Ambulance', 'None', 'Other'], dtype=object)

# %%
df2["AUTHORITY_CONTACTED"].value_counts()
# Out:
# Ambulance    4082
# Police       2982
# None         1945
# Other         991
# Name: AUTHORITY_CONTACTED, dtype: int64

# %%
X=df2[df2["AUTHORITY_CONTACTED"]!="Police"]

# %%
X.head(1)
# Out:
#          TXN_DATE_TIME TRANSACTION_ID CUSTOMER_ID POLICY_NUMBER POLICY_EFF_DT  \
# 1  2020-06-01 00:00:00    TXN00000002   A00008149   PLC00009594    2018-04-21
#
#       LOSS_DT   REPORT_DT INSURANCE_TYPE  PREMIUM_AMOUNT  CLAIM_AMOUNT  ...  \
# 1  2020-05-13  2020-05-18       Property          141.71         26000  ...
#
#   STATE_y POSTAL_CODE_y EMP_ROUTING_NUMBER     EMP_ACCT_NUMBER  \
# 1      AZ         85301           44055451  XBYG14382904542874
#
#                         VENDOR_NAME          ADDRESS_LINE1 ADDRESS_LINE2  \
# 1  Morales, Campbell and Washington  42 West Louise Street             B
#
#            CITY  STATE  POSTAL_CODE
# 1  Fayetteville     AR      72701.0
#
# [1 rows x 53 columns]

# %%
X_updated=X[X["POLICE_REPORT_AVAILABLE"]==1].index
X.loc[update,"AUTHORITY_CONTACTED"]="Police"
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df2.head()
# Out:
#          TXN_DATE_TIME TRANSACTION_ID CUSTOMER_ID POLICY_NUMBER POLICY_EFF_DT  \
# 0  2020-06-01 00:00:00    TXN00000001   A00003822   PLC00008468    2015-06-23
# 1  2020-06-01 00:00:00    TXN00000002   A00008149   PLC00009594    2018-04-21
# 2  2020-06-01 00:00:00    TXN00000003   A00003172   PLC00007969    2019-10-03
# 3  2020-06-01 00:00:00    TXN00000004   A00007572   PLC00009292    2016-11-29
# 4  2020-06-01 00:00:00    TXN00000005   A00008173   PLC00000204    2011-12-26
#
#       LOSS_DT   REPORT_DT INSURANCE_TYPE  PREMIUM_AMOUNT  CLAIM_AMOUNT  ...  \
# 0  2020-05-16  2020-05-21         Health          157.13          9000  ...
# 1  2020-05-13  2020-05-18       Property          141.71         26000  ...
# 2  2020-05-21  2020-05-26       Property          157.24         13000  ...
# 3  2020-05-14  2020-05-19         Health          172.87         16000  ...
# 4  2020-05-17  2020-05-22         Travel           88.53          3000  ...
#
# ...

# %% [markdown]
# Task 6: Business wants to check the Claim Amount for deviation for each transaction, they would
# like you to calculate as follow
# CLAIM_DEVIATION = AVG_CLAIM_AMOUNT_FOR_LAST_30DAYS (same insurance type)
# / CURRENT_CLAIM_AMOUNT
# If the value < 0.5 THEN CLAIM_DEVIATION = 1 ELSE 0
# If there is less than 30 days of transaction history THEN
# -1 Note: LAST_30DAYS does not include current day

# %%
df2_date=pd.to_datetime(df2["TXN_DATE_TIME"].max())# present_date

# %%
df2_date
# Out:
# Timestamp('2021-06-30 00:00:00')

# %%
df2["TXN_DATE_TIME"]=pd.to_datetime(df2["TXN_DATE_TIME"])

# %%
df2_date_30=df2.loc[(df2['TXN_DATE_TIME'] > '2021-05-30') & (df2['TXN_DATE_TIME'] < df2_date)] #past 30 days data

# %%
avg_claim = df2_date_30.groupby('INSURANCE_TYPE').mean()['CLAIM_AMOUNT'].to_dict()

# %%
avg_claim
# Out:
# {'Health': 10904.411764705883,
#  'Life': 52242.857142857145,
#  'Mobile': 378.35820895522386,
#  'Motor': 5573.770491803279,
#  'Property': 24627.906976744187,
#  'Travel': 2800.0}

# %% [markdown]
# Task 7:
# Find All Agents who have worked on more than 2 types of Insurance Claims. Sort them by
# Total Claim Amount Approved under them in descending order

# %%
df2_agent_type= df2.groupby('AGENT_ID')['INSURANCE_TYPE'].nunique()
df2_insurance_types= df2_agent_type >2

# %%
df2_insurance_types=df2_insurance_types[df2_insurance_types].index
df2_insurance_types
# Out:
# Index(['AGENT00001', 'AGENT00003', 'AGENT00004', 'AGENT00005', 'AGENT00006',
#        'AGENT00007', 'AGENT00008', 'AGENT00009', 'AGENT00010', 'AGENT00011',
#        ...
#        'AGENT01191', 'AGENT01192', 'AGENT01193', 'AGENT01194', 'AGENT01195',
#        'AGENT01196', 'AGENT01197', 'AGENT01198', 'AGENT01199', 'AGENT01200'],
#       dtype='object', name='AGENT_ID', length=1164)

# %% [markdown]
# Task 8:
# Mobile & Travel Insurance premium are discounted by 10%
# Health and Property Insurance premium are increased by 7%
# Life and Motor Insurance premium are marginally increased by 2%
# What will be overall change in % of the Premium Amount Collected for all these Customer?

# %%
df2_premier = df2.groupby('INSURANCE_TYPE').sum()['PREMIUM_AMOUNT'].to_dict()
df2_premier
# Out:
# {'Health': 252455.73,
#  'Life': 125621.22,
#  'Mobile': 15191.42,
#  'Motor': 165391.98,
#  'Property': 202285.83,
#  'Travel': 124139.77}

# %%
# Mobile & Travel discounted= 10%
df2_premier['Mobile']*=0.9
df2_premier['Travel']*=0.9
# Health and Property increases = 7%
df2_premier['Health']*=1.07
df2_premier['Property']*=1.07
# Life and Motor increased= 2%
df2_premier['Life']*=1.02
df2_premier['Motor']*=1.02

# %%
new_premier = sum(df2_premier.values())
old_premier = df2['PREMIUM_AMOUNT'].sum()
(new_premier-old_premier)*100/old_premier
# Out:
# 2.5253848397435457

# %%
print(old_premier,new_premier)
# Out:
# 885085.95 907437.7764000001

# %% [markdown]
# Task 11:
# Find all low performing agents i.e. employees who are in the bottom 5 percentile based
# on Claims worked by them.

# %%
df2_low_performing = df2.groupby('AGENT_ID').sum().quantile(0.05)['CLAIM_AMOUNT']

# %%
low_performing_grouped = df2.groupby('AGENT_ID').sum()

# %%
low_performing =low_performing_grouped[low_performing_grouped['CLAIM_AMOUNT']<=df2_low_performing][['CLAIM_AMOUNT']]
low_performing
# Out:
#             CLAIM_AMOUNT
# AGENT_ID
# AGENT00006         22400
# AGENT00014          7400
# AGENT00016         27000
# AGENT00085         25700
# AGENT00088         27700
# AGENT00091         30000
# AGENT00098         28200
# AGENT00134         22000
# AGENT00149         28900
# AGENT00156         13200
# AGENT00172         22200
# AGENT00185         16100
# AGENT00186         27700
# AGENT00188         28400
# AGENT00197         18500
# AGENT00252         20000
# AGENT00263         11500
# AGENT00275         16200
# AGENT00279         28000
# AGENT00300         12600
# AGENT00310         28800
# AGENT00316         22200
# AGENT00351         21700
# AGENT00425         17800
# AGENT00442         30300
# AGENT00536         20000
# AGENT00562         21100
# AGENT00571         24200
# AGENT00585         16600
# AGENT00590         22200
# AGENT00604          5500
# AGENT00621          5300
# AGENT00628          6100
# AGENT00672         21300
# AGENT00689         13700
# ...
